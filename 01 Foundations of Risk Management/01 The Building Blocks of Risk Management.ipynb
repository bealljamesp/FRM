# %%
# System Check for FRM Quant Lab
import sys
import os
import pandas as pd
import numpy as np
import scipy.stats as stats

# 1. Verify Virtual Environment is active
print(f"Python Executable: {sys.executable}") 

# 2. Verify Working Directory (should be Documents\Math\Notebooks\FRM)
print(f"CWD: {os.getcwd()}")

# 3. Quick Math Test (Verify Scipy is ready for FRM stats)
# Calculate the Z-score for a 95% one-tailed VaR
z_score = stats.norm.ppf(0.95)
print(f"95% Confidence Z-Score: {z_score:.4f}") # Should be 1.6449
# Out:
# Python Executable: C:\Users\beall\Documents\Math\Notebooks\frm\venv\Scripts\python.exe
# CWD: C:\Users\beall\Documents\Math\Notebooks\frm\01 Foundations of Risk Management
# 95% Confidence Z-Score: 1.6449
